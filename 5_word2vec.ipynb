# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str_any(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5234, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %%
print(reverse_dictionary[data[0]])
# Out:
# anarchism

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(1,1),(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 1 and skip_window = 1:
#     batch: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#     labels: ['anarchism', 'a', 'term', 'a', 'term', 'of', 'abuse', 'against']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['originated', 'term', 'anarchism', 'a', 'term', 'of', 'as', 'originated']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.753084
# Nearest to only: shelters, genghis, hays, homilies, hora, lionheart, haart, asceticism,
# Nearest to three: fez, adulthood, delegation, myst, scipione, fluorescent, satyr, khalq,
# Nearest to called: websites, elisa, internalism, hideki, ferguson, ppp, garonne, topical,
# Nearest to up: thessaly, inducted, nelson, senate, leviathan, ejaculate, flutie, copley,
# Nearest to in: hjalmar, kierkegaard, cli, interact, dme, dredging, ashcroft, indonesia,
# Nearest to d: haeckel, arabidopsis, watch, consilience, kahan, griffon, jacobus, raider,
# Nearest to the: hannover, antiquaries, immature, humphrey, physical, meander, gulden, cris,
# Nearest to he: pullback, furlongs, metrical, horseshoes, motivations, assamese, dolby, tait,
# Nearest to are: cider, hezekiah, judging, asymptotes, biochemical, mongolians, eminence, modes,
# Nearest to of: proclaiming, constructivists, relaxation, origins, elvis, puzzles, gladius, fangio,
# Nearest to new: embassies, reflective, frankenheimer, luxuriant, loci, formats, fraught, promotions,
# Nearest to between: danzig, szil, boito, eee, reconstructionist, perturbation, divert, hakka,
# Nearest to th: mango, pulitzer, react, void, ford, jess, bette, ruins,
# Nearest to system: blossomed, liner, wuhan, ababa, avesta, studies, inverses, ion,
# Nearest to its: midwifery, emits, fahd, time, cyberpunk, amiga, extensions, zama,
# Nearest to known: powerpoint, greenman, tenor, overman, tensile, mermaid, coincident, coastlines,
# Average loss at step 2000: 4.374800
# Average loss at step 4000: 3.869553
# Average loss at step 6000: 3.787453
# Average loss at step 8000: 3.686689
# Average loss at step 10000: 3.618505
# Nearest to only: absent, genghis, righteous, tangier, blowfish, dispose, also, virginity,
# Nearest to three: five, four, six, eight, seven, two, nine, zero,
# Nearest to called: garonne, mabo, ferguson, biodiversity, elisa, internalism, alsos, pluck,
# Nearest to up: thessaly, excited, transfection, him, weymouth, finches, flutie, discrimination,
# Nearest to in: on, of, at, during, from, with, and, falstaff,
# Nearest to d: watch, kahan, arabidopsis, comerica, spoilage, griffon, consilience, crimea,
# Nearest to the: a, its, this, his, their, an, donatello, intestine,
# Nearest to he: it, they, she, who, assamese, there, emails, dispositions,
# Nearest to are: were, is, have, was, cider, include, be, though,
# Nearest to of: in, at, for, same, from, on, truck, numeral,
# Nearest to new: frankenheimer, near, reflective, embassies, fraught, legume, formats, gobind,
# Nearest to between: with, in, szil, hostages, brenner, athletics, improperly, shortest,
# Nearest to th: mango, pulitzer, septimius, four, react, elfin, reconstructionism, ford,
# Nearest to system: studies, wuhan, bengals, derive, groupings, ion, corvus, blossomed,
# Nearest to its: the, their, his, fluent, geologically, epithets, miracles, herbicides,
# Nearest to known: overman, hazard, powerpoint, such, jj, cta, rpp, chiral,
# Average loss at step 12000: 3.604863
# Average loss at step 14000: 3.572690
# Average loss at step 16000: 3.407888
# Average loss at step 18000: 3.457162
# Average loss at step 20000: 3.540161
# Nearest to only: absent, dispose, entrant, ridden, never, we, tangier, broca,
# Nearest to three: four, five, seven, six, two, eight, zero, one,
# Nearest to called: garonne, abbas, mabo, exemplar, known, sees, pluck, formative,
# Nearest to up: excited, him, transfection, thessaly, out, bristol, discrimination, weymouth,
# Nearest to in: at, from, with, under, during, adalbert, on, for,
# Nearest to d: b, arabidopsis, spoilage, griffon, hypercard, comerica, tris, niigata,
# Nearest to the: its, their, his, this, a, an, some, her,
# Nearest to he: it, she, they, who, there, prostitutes, which, totality,
# Nearest to are: were, is, have, was, though, include, andover, utopia,
# Nearest to of: for, femme, and, in, madhava, ajmer, coastal, rpgs,
# Nearest to new: embassies, luxuriant, legume, vivian, frankenheimer, fraught, decadence, allocations,
# Nearest to between: against, with, from, in, hostages, szil, improperly, treatises,
# Nearest to th: pulitzer, mango, four, septimius, jaeger, tadeusz, pamphlets, reconstructionism,
# Nearest to system: derive, studies, mozzarella, mass, avesta, liner, groupings, dusseldorf,
# Nearest to its: their, his, the, herbicides, fluent, her, this, epithets,
# Nearest to known: overman, such, used, well, hazard, possible, chiral, called,
# Average loss at step 22000: 3.501998
# Average loss at step 24000: 3.491017
# Average loss at step 26000: 3.481162
# Average loss at step 28000: 3.484571
# Average loss at step 30000: 3.497527
# Nearest to only: absent, assize, reference, claudia, broca, ridden, never, question,
# Nearest to three: five, four, seven, six, eight, two, nine, zero,
# Nearest to called: abbas, sees, mabo, considered, garonne, known, decreasing, formative,
# Nearest to up: him, out, excited, off, finches, them, transfection, qm,
# Nearest to in: during, under, at, on, of, until, and, from,
# Nearest to d: b, arabidopsis, comerica, hypercard, lightbulb, mistaking, kipling, spoilage,
# Nearest to the: their, its, his, tagged, these, longinus, some, this,
# Nearest to he: it, she, they, who, there, prostitutes, never, averse,
# Nearest to are: were, is, have, include, andover, be, venom, though,
# Nearest to of: in, for, from, femme, and, rpgs, mambo, martinique,
# Nearest to new: legume, embassies, warrants, separate, reflective, fraught, decadence, landowners,
# Nearest to between: with, against, from, voc, szil, treatises, earmarked, in,
# Nearest to th: pulitzer, mango, nd, septimius, gonzales, luther, jaeger, five,
# Nearest to system: studies, derive, dusseldorf, mass, lecturer, lavinia, evidence, mozzarella,
# Nearest to its: their, the, his, her, herbicides, geologically, karakoram, walloon,
# Nearest to known: used, overman, well, such, possible, rpp, called, hazard,
# Average loss at step 32000: 3.505069
# Average loss at step 34000: 3.497551
# Average loss at step 36000: 3.449347
# Average loss at step 38000: 3.307799
# Average loss at step 40000: 3.429717
# Nearest to only: absent, never, no, seen, assize, righteous, blowfish, itself,
# Nearest to three: four, five, six, two, seven, eight, nine, zero,
# Nearest to called: considered, sees, abbas, decreasing, mabo, formative, used, ayyash,
# Nearest to up: out, him, off, them, excited, bristol, finches, transfection,
# Nearest to in: during, and, at, on, for, of, until, from,
# Nearest to d: b, consilience, arabidopsis, hypercard, gelatin, comerica, kipling, mistaking,
# Nearest to the: his, their, this, each, any, its, a, our,
# Nearest to he: she, it, they, who, there, never, prostitutes, i,
# Nearest to are: were, have, is, include, be, while, these, but,
# Nearest to of: truck, in, martinique, gypsy, coastal, for, mua, rpgs,
# Nearest to new: separate, legume, ctus, discontinuous, luxuriant, bnetd, tremors, succession,
# Nearest to between: with, against, from, treatises, szil, voc, technologically, within,
# Nearest to th: mango, nd, pulitzer, gonzales, septimius, seven, shambles, tadeusz,
# Nearest to system: systems, mass, studies, evidence, derive, bicycles, groupings, engineering,
# Nearest to its: their, his, her, the, dominate, unix, herbicides, miracles,
# Nearest to known: such, used, overman, well, possible, powerpoint, touring, important,
# Average loss at step 42000: 3.438953
# Average loss at step 44000: 3.454253
# Average loss at step 46000: 3.450924
# Average loss at step 48000: 3.357610
# Average loss at step 50000: 3.386387
# Nearest to only: absent, never, dispose, now, righteous, mekong, coloureds, assize,
# Nearest to three: four, six, eight, five, seven, two, nine, zero,
# Nearest to called: considered, abbas, used, sees, ayyash, eddic, mabo, biodiversity,
# Nearest to up: out, off, them, him, excited, transfection, finches, down,
# Nearest to in: during, from, since, of, under, between, on, and,
# Nearest to d: b, f, m, r, arabidopsis, consilience, prequels, gelatin,
# Nearest to the: its, their, this, his, a, any, donatello, ponty,
# Nearest to he: she, it, they, who, there, never, this, prostitutes,
# Nearest to are: were, is, have, these, include, be, prelates, those,
# Nearest to of: in, including, and, femme, shaved, like, outcast, martinique,
# Nearest to new: separate, ellington, track, abrams, sonar, anteaters, succession, reflective,
# Nearest to between: with, against, in, voc, treatises, within, among, szil,
# Nearest to th: nd, gonzales, four, mango, pulitzer, shambles, septimius, hel,
# Nearest to system: systems, mass, bicycles, ababa, evidence, studies, engineering, pluralist,
# Nearest to its: their, his, the, her, dominate, geologically, access, fluent,
# Nearest to known: used, such, overman, possible, well, served, important, part,
# Average loss at step 52000: 3.436966
# Average loss at step 54000: 3.429260
# Average loss at step 56000: 3.439820
# Average loss at step 58000: 3.398755
# Average loss at step 60000: 3.396012
# Nearest to only: also, still, never, absent, assize, dispose, first, mekong,
# Nearest to three: four, five, six, eight, seven, two, nine, zero,
# Nearest to called: considered, used, abbas, known, decreasing, required, ausgleich, sees,
# Nearest to up: off, out, him, them, down, excited, finches, transfection,
# Nearest to in: during, within, on, since, at, near, until, from,
# Nearest to d: b, m, r, c, f, mistaking, conjunct, arabidopsis,
# Nearest to the: its, their, a, any, this, some, each, ediacaran,
# Nearest to he: she, it, they, who, there, never, we, prostitutes,
# Nearest to are: were, is, have, include, although, including, those, these,
# Nearest to of: gypsy, martinique, including, shaved, in, and, for, same,
# Nearest to new: separate, apollo, frankenheimer, legume, abrams, hinterlands, vivian, track,
# Nearest to between: with, against, among, within, around, treatises, brenner, in,
# Nearest to th: nd, five, gonzales, six, four, pulitzer, bc, tadeusz,
# Nearest to system: systems, mass, bicycles, company, studies, engineering, evidence, program,
# Nearest to its: their, his, her, the, whose, herbicides, geologically, chained,
# Nearest to known: used, overman, such, possible, considered, well, clear, important,
# Average loss at step 62000: 3.236411
# Average loss at step 64000: 3.255685
# Average loss at step 66000: 3.404698
# Average loss at step 68000: 3.397525
# Average loss at step 70000: 3.356295
# Nearest to only: never, absent, still, mat, assize, righteous, both, also,
# Nearest to three: four, six, five, two, seven, eight, zero, nine,
# Nearest to called: considered, abbas, used, named, known, sees, decreasing, ecozone,
# Nearest to up: off, out, them, down, him, excited, transfection, inducted,
# Nearest to in: within, during, on, for, from, of, at, cli,
# Nearest to d: b, f, r, arabidopsis, conjunct, triumvirate, mistaking, consilience,
# Nearest to the: its, their, any, this, a, these, each, some,
# Nearest to he: she, it, they, there, we, who, never, assamese,
# Nearest to are: were, have, is, include, these, be, including, although,
# Nearest to of: including, shaved, for, include, in, although, original, ajmer,
# Nearest to new: separate, sonar, logical, certain, muskegon, fingerprint, ellington, damn,
# Nearest to between: with, among, within, treatises, from, against, around, linnean,
# Nearest to th: nd, gonzales, bc, rd, pulitzer, mango, remade, four,
# Nearest to system: systems, program, mass, company, companies, acapulco, untersuchungen, engineering,
# Nearest to its: their, the, his, her, whose, herbicides, chained, egyptologist,
# Nearest to known: used, overman, such, considered, possible, well, described, called,
# Average loss at step 72000: 3.373456
# Average loss at step 74000: 3.346601
# Average loss at step 76000: 3.321571
# Average loss at step 78000: 3.352681
# Average loss at step 80000: 3.379877
# Nearest to only: assize, absent, doesburg, mat, still, persuaded, awarded, righteous,
# Nearest to three: six, four, seven, five, eight, two, nine, zero,
# Nearest to called: considered, used, known, abbas, named, nasr, brundtland, expert,
# Nearest to up: off, out, him, down, them, excited, transfection, inducted,
# Nearest to in: during, within, on, at, until, since, of, under,
# Nearest to d: b, f, m, consilience, conjunct, popper, ie, umberto,
# Nearest to the: their, its, prosperous, a, this, his, our, yyyy,
# Nearest to he: she, it, they, there, who, we, never, immediately,
# Nearest to are: were, include, have, is, these, those, although, demonstrably,
# Nearest to of: including, in, mindanao, although, under, shaved, femme, hypopituitarism,
# Nearest to new: separate, ellington, embassies, ethidium, muskegon, bnetd, fingerprint, frankenheimer,
# Nearest to between: among, within, with, treatises, over, around, against, szil,
# Nearest to th: nd, bc, gonzales, six, mango, jutta, five, rd,
# Nearest to system: systems, program, mass, engineering, company, untersuchungen, extradited, injured,
# Nearest to its: their, his, her, the, herbicides, whose, steyn, egyptologist,
# Nearest to known: used, overman, such, considered, described, regarded, possible, called,
# Average loss at step 82000: 3.406312
# Average loss at step 84000: 3.411940
# Average loss at step 86000: 3.390587
# Average loss at step 88000: 3.352073
# Average loss at step 90000: 3.368641
# Nearest to only: assize, no, absent, bending, never, applet, contract, purchase,
# Nearest to three: five, four, two, seven, eight, six, nine, zero,
# Nearest to called: considered, used, named, abbas, known, ecozone, designated, goya,
# Nearest to up: off, out, down, him, them, excited, together, insensible,
# Nearest to in: during, within, under, with, of, until, from, near,
# Nearest to d: b, m, f, qquad, mbox, conjunct, germaine, r,
# Nearest to the: its, their, this, his, wels, bitumen, a, any,
# Nearest to he: she, it, they, there, who, we, later, originally,
# Nearest to are: were, is, include, have, these, although, those, while,
# Nearest to of: including, for, in, during, mindanao, afp, under, recommending,
# Nearest to new: separate, pcm, ellington, magnify, luxuriant, muskegon, bnetd, swap,
# Nearest to between: within, among, with, treatises, from, around, against, over,
# Nearest to th: nd, four, bc, one, st, seven, eight, tadeusz,
# Nearest to system: systems, mass, extradited, program, domingue, alhazen, process, mozzarella,
# Nearest to its: their, his, her, the, whose, your, elaboration, our,
# Nearest to known: used, such, overman, described, possible, viewed, regarded, considered,
# Average loss at step 92000: 3.396879
# Average loss at step 94000: 3.254730
# Average loss at step 96000: 3.362131
# Average loss at step 98000: 3.244548
# Average loss at step 100000: 3.358165
# Nearest to only: never, assize, still, no, always, absent, attacker, landslide,
# Nearest to three: four, five, six, seven, eight, two, nine, zero,
# Nearest to called: named, considered, abbas, used, known, disadvantaged, designated, brundtland,
# Nearest to up: off, out, down, him, them, excited, transfection, playfulness,
# Nearest to in: during, within, on, at, from, throughout, under, around,
# Nearest to d: b, minsk, popper, c, f, mistaking, triumvirate, hypercard,
# Nearest to the: their, its, his, some, your, paleontologist, a, sesotho,
# Nearest to he: she, it, they, there, who, we, never, this,
# Nearest to are: were, have, include, is, those, although, be, these,
# Nearest to of: including, martinique, gypsy, cantilever, in, include, original, iota,
# Nearest to new: separate, different, ellington, bnetd, muskegon, sica, wearing, computer,
# Nearest to between: among, with, within, around, treatises, through, szil, over,
# Nearest to th: nd, four, st, rd, tadeusz, gonzales, monosodium, jutta,
# Nearest to system: systems, engineering, domingue, program, process, extradited, injured, alhazen,
# Nearest to its: their, his, the, her, whose, egyptologist, apotheosis, notions,
# Nearest to known: used, such, possible, overman, viewed, described, considered, referred,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
# Create a new generate_batch function for cbow.
# For bag_window it should return a random selection of nearby words within the window, all labelled with the word at the center of the window.

data_index = 0

def generate_batch(batch_size, bag_window):
  global data_index
  span = 2 * bag_window + 1
  assert batch_size % num_skips == 0
  batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    buffer_temp = list(buffer)
    labels[i][0] = buffer_temp.pop(bag_window)
    batch[i] = buffer_temp
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:9]])

for bag_window in [1,2,4]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, bag_window=bag_window)
    print('\nwith bag_window = %d:' % (bag_window))
    print('    batch:', [[reverse_dictionary[word] for word in data.reshape(2*bag_window)] for data in batch.reshape(8,-1)])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of'], ['term', 'abuse'], ['of', 'first'], ['abuse', 'used'], ['first', 'against']]
#     labels: ['originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first'], ['term', 'of', 'first', 'used'], ['of', 'abuse', 'used', 'against'], ['abuse', 'first', 'against', 'early'], ['first', 'used', 'early', 'working']]
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']
#
# with bag_window = 4:
#     batch: [['anarchism', 'originated', 'as', 'a', 'of', 'abuse', 'first', 'used'], ['originated', 'as', 'a', 'term', 'abuse', 'first', 'used', 'against'], ['as', 'a', 'term', 'of', 'first', 'used', 'against', 'early'], ['a', 'term', 'of', 'abuse', 'used', 'against', 'early', 'working'], ['term', 'of', 'abuse', 'first', 'against', 'early', 'working', 'class'], ['of', 'abuse', 'first', 'used', 'early', 'working', 'class', 'radicals'], ['abuse', 'first', 'used', 'against', 'working', 'class', 'radicals', 'including'], ['first', 'used', 'against', 'early', 'class', 'radicals', 'including', 'the']]
#     labels: ['term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working']

# %%
# Define model
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
bag_window = 2 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent.
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, 2 * bag_window])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.reduce_mean(tf.nn.embedding_lookup(embeddings, train_dataset),1)
  print(embed.shape)
  print(tf.reduce_sum(embed,1).shape)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# (128, 128)
# (128,)

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, bag_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 6.901254
# Nearest to as: brunel, edt, afield, tome, unbelievable, noumenon, elan, sbc,
# Nearest to may: robbins, companies, breech, bennett, movies, monsters, okeh, joliet,
# Nearest to is: allotrope, senseless, surveyed, pelletier, tropical, lydians, covalent, games,
# Nearest to new: provided, diphtheria, hoe, lito, amoeboid, prokaryote, diversification, toluene,
# Nearest to on: tlc, gasp, origination, tess, fusiliers, potawatomi, rev, green,
# Nearest to time: carnivores, august, fireball, workmanship, sergeant, secretory, gertrude, typhoid,
# Nearest to between: drinkers, businessweek, privileges, venerable, eschenbach, danmarks, vegetarian, nesmith,
# Nearest to a: uncharacteristically, keyword, mtv, bisected, paradox, rossby, wojciech, intrauterine,
# Nearest to war: affiliation, newnode, fashionable, healy, eustace, soybeans, musicians, cowboys,
# Nearest to while: abeken, nasional, hausa, calendars, dickey, corresponds, subversion, choke,
# Nearest to s: macarthur, safe, coefficients, evaded, settler, pva, eliezer, cache,
# Nearest to these: aron, whist, wangenheim, endure, ret, reddish, presenter, practising,
# Nearest to to: goss, touchdowns, tyrone, hustler, marcus, coup, msm, medica,
# Nearest to often: improbable, funds, whittaker, forti, yolk, superhero, honolulu, bearded,
# Nearest to this: flightless, curran, prequels, departments, tunku, vermin, bryozoa, uv,
# Nearest to used: aged, indecent, exogenous, bregovi, feel, attentive, pentameter, routledge,
# Average loss at step 2000: 4.172559
# Average loss at step 4000: 3.609905
# Average loss at step 6000: 3.474998
# Average loss at step 8000: 3.405033
# Average loss at step 10000: 3.217159
# Nearest to as: afield, andamans, famicom, tome, approved, cooled, hibiscus, kilogram,
# Nearest to may: should, could, can, must, will, would, might, companies,
# Nearest to is: was, are, has, were, allotrope, be, averroes, smallpox,
# Nearest to new: diphtheria, provided, mahendra, braille, brod, amoeboid, quality, bomis,
# Nearest to on: gasp, in, during, green, sadducees, jericho, spectrum, taxable,
# Nearest to time: carnivores, maul, motilal, workmanship, adaption, clinically, karo, typhoid,
# Nearest to between: into, threefold, with, in, niva, jumping, vegetarian, acadia,
# Nearest to a: an, the, keyword, uncharacteristically, raj, any, linux, britain,
# Nearest to war: affiliation, musicians, vii, cowboys, negri, healy, ldap, burgos,
# Nearest to while: abeken, than, ephraim, hausa, like, nasional, dickey, atheist,
# Nearest to s: his, gallery, nottingham, pitts, hide, transport, cache, multiples,
# Nearest to these: some, other, they, all, allegedly, many, the, objectivity,
# Nearest to to: goss, touchdowns, will, nonpartisan, tyrone, memex, kri, against,
# Nearest to often: improbable, usually, my, funds, whittaker, traveling, havens, kwame,
# Nearest to this: it, an, justifiably, evatt, hast, eldest, what, curran,
# Nearest to used: aged, parakeet, tory, worldcom, candlemas, attentive, fistful, viable,
# Average loss at step 12000: 3.291711
# Average loss at step 14000: 3.267760
# Average loss at step 16000: 3.243351
# Average loss at step 18000: 3.264724
# Average loss at step 20000: 3.195451
# Nearest to as: afield, hibiscus, aves, tenderness, kilogram, brunel, andamans, approved,
# Nearest to may: should, can, will, could, must, would, might, cannot,
# Nearest to is: was, are, has, be, were, devi, footy, laypeople,
# Nearest to new: diphtheria, mahendra, amoeboid, xanadu, tissue, braille, prokaryote, bomis,
# Nearest to on: gasp, in, jericho, taxable, berenson, sadducees, statehouse, spectrum,
# Nearest to time: carnivores, clinically, ages, maul, year, motilal, workmanship, ends,
# Nearest to between: into, with, juggalo, threefold, social, jericho, in, jumping,
# Nearest to a: another, uncharacteristically, any, linux, keyword, britain, monrovia, coursework,
# Nearest to war: musicians, affiliation, burgos, ldap, vii, berets, healy, nihonshoki,
# Nearest to while: among, abeken, than, like, hausa, ephraim, identically, xi,
# Nearest to s: gallery, his, loretta, nottingham, whose, trie, cache, anselm,
# Nearest to these: other, some, many, allegedly, all, they, several, different,
# Nearest to to: will, goss, can, touchdowns, would, chunks, trampled, kri,
# Nearest to often: usually, improbable, still, now, my, whittaker, traveling, holder,
# Nearest to this: it, another, what, conway, prequels, an, crm, lili,
# Nearest to used: known, parakeet, regarded, tory, ota, intentional, referred, available,
# Average loss at step 22000: 3.164553
# Average loss at step 24000: 3.182415
# Average loss at step 26000: 3.158386
# Average loss at step 28000: 3.153815
# Average loss at step 30000: 3.153035
# Nearest to as: afield, famicom, aves, dynasties, hibiscus, ascertaining, tenderness, andamans,
# Nearest to may: can, should, must, might, could, would, will, cannot,
# Nearest to is: was, are, has, be, devi, became, holds, kilby,
# Nearest to new: diphtheria, rothbard, xanadu, tissue, amoeboid, mahendra, downloadable, braille,
# Nearest to on: taxable, gasp, upon, statehouse, jericho, at, sadducees, blockbusters,
# Nearest to time: carnivores, ages, clinically, maul, least, year, point, bushnell,
# Nearest to between: into, with, juggalo, bridges, social, jumping, threefold, jericho,
# Nearest to a: another, the, any, keyword, finitely, positional, pantheistic, uncharacteristically,
# Nearest to war: affiliation, musicians, ldap, burgos, berets, vii, nihonshoki, healy,
# Nearest to while: among, than, abeken, identically, xi, like, hausa, ephraim,
# Nearest to s: his, nottingham, whose, gallery, loretta, cache, trie, anselm,
# Nearest to these: other, some, many, several, different, allegedly, all, various,
# Nearest to to: would, will, goss, memex, could, tyrone, can, may,
# Nearest to often: usually, still, improbable, sometimes, my, whittaker, now, traveling,
# Nearest to this: it, another, which, what, crm, that, smartest, conway,
# Nearest to used: known, regarded, referred, available, parakeet, intentional, dyslexic, ota,
# Average loss at step 32000: 3.117884
# Average loss at step 34000: 2.979055
# Average loss at step 36000: 3.101330
# Average loss at step 38000: 3.063639
# Average loss at step 40000: 3.057978
# Nearest to as: famicom, afield, ascertaining, dynasties, tome, brunel, andamans, disagreeable,
# Nearest to may: should, can, might, could, must, would, will, cannot,
# Nearest to is: was, are, has, devi, became, holds, be, makes,
# Nearest to new: burying, diphtheria, downloadable, xanadu, prokaryote, rothbard, kentucky, tissue,
# Nearest to on: upon, gasp, taxable, statehouse, sip, desertification, jericho, depeche,
# Nearest to time: clinically, carnivores, ages, least, combines, mesolithic, bushnell, maul,
# Nearest to between: into, with, over, juggalo, dealers, jericho, jumping, sanchez,
# Nearest to a: another, the, finitely, pantheistic, every, uncharacteristically, any, keyword,
# Nearest to war: ldap, affiliation, burgos, berets, musicians, nihonshoki, vii, yetzer,
# Nearest to while: among, than, like, identically, however, and, panes, violations,
# Nearest to s: his, cache, archdiocese, anselm, trie, nottingham, amenities, whose,
# Nearest to these: other, various, different, some, many, several, allegedly, all,
# Nearest to to: would, will, might, goss, against, touchdowns, may, tyrone,
# Nearest to often: usually, still, sometimes, commonly, improbable, now, whittaker, bled,
# Nearest to this: it, another, which, what, shinto, conway, gardnerian, smartest,
# Nearest to used: regarded, referred, available, known, intentional, written, parakeet, designed,
# Average loss at step 42000: 3.072075
# Average loss at step 44000: 3.096116
# Average loss at step 46000: 3.046834
# Average loss at step 48000: 3.075792
# Average loss at step 50000: 2.997176
# Nearest to as: famicom, afield, ascertaining, dynasties, moshe, aves, tome, plea,
# Nearest to may: should, can, might, could, must, would, will, cannot,
# Nearest to is: was, are, has, devi, became, be, holds, makes,
# Nearest to new: prokaryote, downloadable, burying, xanadu, kentucky, tissue, medina, mahendra,
# Nearest to on: upon, taxable, gasp, statehouse, desertification, sip, condensed, spells,
# Nearest to time: clinically, least, ages, combines, carnivores, ends, mesolithic, bushnell,
# Nearest to between: into, with, over, bridges, juggalo, sanchez, jericho, within,
# Nearest to a: another, the, every, any, pantheistic, finitely, uncharacteristically, monody,
# Nearest to war: ldap, burgos, berets, musicians, affiliation, vii, yetzer, cowboys,
# Nearest to while: than, however, among, like, identically, when, panes, although,
# Nearest to s: his, trie, cache, whose, loretta, kashmir, archdiocese, anselm,
# Nearest to these: other, different, various, several, some, many, which, mechagodzilla,
# Nearest to to: would, will, goss, shall, tyrone, might, must, can,
# Nearest to often: usually, sometimes, commonly, still, now, generally, whittaker, frequently,
# Nearest to this: which, it, another, what, aster, dissipated, shinto, crm,
# Nearest to used: referred, available, regarded, known, designed, written, intentional, parakeet,
# Average loss at step 52000: 2.977128
# Average loss at step 54000: 2.993548
# Average loss at step 56000: 3.026216
# Average loss at step 58000: 2.907553
# Average loss at step 60000: 2.977886
# Nearest to as: famicom, afield, ascertaining, dynasties, tome, hibiscus, bilbao, schuschnigg,
# Nearest to may: can, might, should, must, could, would, will, cannot,
# Nearest to is: was, are, has, holds, be, became, becomes, refers,
# Nearest to new: prokaryote, downloadable, tissue, xanadu, amoeboid, printers, affiliates, mahendra,
# Nearest to on: upon, taxable, gasp, statehouse, sip, burbank, blockbusters, floppies,
# Nearest to time: least, ages, clinically, point, combines, ends, maul, bushnell,
# Nearest to between: into, with, over, bridges, sanchez, maritime, juggalo, thus,
# Nearest to a: another, the, every, keyword, any, finitely, pantheistic, refrains,
# Nearest to war: berets, affiliation, ldap, burgos, musicians, nihonshoki, vii, sarawak,
# Nearest to while: than, among, and, although, like, however, panes, identically,
# Nearest to s: his, cache, trie, loretta, whose, archdiocese, kashmir, multiples,
# Nearest to these: various, other, different, several, some, which, ribeira, many,
# Nearest to to: will, goss, would, towards, kri, trampled, tyrone, atiyah,
# Nearest to often: usually, sometimes, commonly, still, generally, frequently, widely, now,
# Nearest to this: it, which, another, what, gardnerian, accrington, crm, shinto,
# Nearest to used: referred, regarded, available, designed, known, written, transcribed, dahalo,
# Average loss at step 62000: 2.970297
# Average loss at step 64000: 2.945244
# Average loss at step 66000: 2.904056
# Average loss at step 68000: 2.859979
# Average loss at step 70000: 2.906288
# Nearest to as: famicom, ascertaining, afield, dynasties, flies, meltdown, curfew, moshe,
# Nearest to may: should, might, can, must, could, will, would, cannot,
# Nearest to is: was, are, holds, has, refers, makes, remains, becomes,
# Nearest to new: xanadu, shoot, prokaryote, mystics, printers, downloadable, affiliates, burying,
# Nearest to on: upon, taxable, gasp, statehouse, sip, blockbusters, desertification, burbank,
# Nearest to time: clinically, least, combines, ages, bushnell, point, mesolithic, maul,
# Nearest to between: into, with, over, bridges, sanchez, thus, maritime, apteryx,
# Nearest to a: another, the, every, any, keyword, pantheistic, uncharacteristically, finitely,
# Nearest to war: ldap, affiliation, berets, burgos, musicians, nihonshoki, wars, cowboys,
# Nearest to while: than, although, among, however, and, when, but, identically,
# Nearest to s: his, multiples, cache, whose, kashmir, pleading, trie, ripping,
# Nearest to these: various, different, other, several, ribeira, many, certain, which,
# Nearest to to: will, would, might, goss, must, towards, shall, tyrone,
# Nearest to often: usually, sometimes, commonly, still, generally, frequently, widely, now,
# Nearest to this: which, it, another, what, dissipated, aster, shinto, lili,
# Nearest to used: available, referred, regarded, designed, known, written, seen, defined,
# Average loss at step 72000: 2.950709
# Average loss at step 74000: 2.844578
# Average loss at step 76000: 2.888913
# Average loss at step 78000: 2.947350
# Average loss at step 80000: 2.942087
# Nearest to as: famicom, curfew, ascertaining, disagreeable, afield, meltdown, dynasties, moshe,
# Nearest to may: might, can, should, must, could, would, will, cannot,
# Nearest to is: was, are, becomes, makes, remains, has, holds, became,
# Nearest to new: xanadu, prokaryote, printers, mystics, shoot, downloadable, mahendra, amoeboid,
# Nearest to on: upon, gasp, statehouse, sip, taxable, emulsion, blockbusters, tupac,
# Nearest to time: clinically, least, point, ages, ends, combines, maul, bushnell,
# Nearest to between: with, into, bridges, sanchez, maritime, freezes, juggalo, over,
# Nearest to a: another, every, keyword, any, the, denny, pantheistic, finitely,
# Nearest to war: wars, ldap, affiliation, nihonshoki, berets, insights, egypt, musicians,
# Nearest to while: although, however, than, when, and, where, like, spawned,
# Nearest to s: his, whose, cache, ripping, lebesgue, trie, multiples, archdiocese,
# Nearest to these: different, various, other, several, ribeira, which, certain, matching,
# Nearest to to: would, will, towards, goss, might, shall, must, tyrone,
# Nearest to often: usually, sometimes, commonly, still, generally, frequently, now, widely,
# Nearest to this: which, it, another, what, aster, dissipated, gardnerian, conway,
# Nearest to used: available, referred, regarded, designed, known, written, seen, found,
# Average loss at step 82000: 2.817428
# Average loss at step 84000: 2.917208
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-e7c413b2c034> in <module>()
#       9       batch_size, bag_window)
#      10     feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
# ---> 11     _, l = session.run([optimizer, loss], feed_dict=feed_dict)
#      12     average_loss += l
#      13     if step % 2000 == 0:
#
# ~/miniconda3/envs/jupyter/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     776     try:
#     777       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 778                          run_metadata_ptr)
#     779       if run_metadata:
#     780         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/miniconda3/envs/jupyter/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     980     if final_fetches or final_targets:
#     981       results = self._do_run(handle, final_targets, final_fetches,
# --> 982                              feed_dict_string, options, run_metadata)
#     983     else:
#     984       results = []
#
# ~/miniconda3/envs/jupyter/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1030     if handle is None:
#    1031       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1032                            target_list, options, run_metadata)
#    1033     else:
#    1034       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# ~/miniconda3/envs/jupyter/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1037   def _do_call(self, fn, *args):
#    1038     try:
# -> 1039       return fn(*args)
#    1040     except errors.OpError as e:
#    1041       message = compat.as_text(e.message)
#
# ~/miniconda3/envs/jupyter/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1019         return tf_session.TF_Run(session, options,
#    1020                                  feed_dict, fetch_list, target_list,
# -> 1021                                  status, run_metadata)
#    1022
#    1023     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])
